# %%
# %load_ext autoreload
# %autoreload 2
from stock_prediction.data_exploration.kaggle_etfs import load_etfs_data
from stock_prediction.commons import PANDAS_STYLE_VERTICAL_COLNAMES

# %% [markdown]
# # Rough Performance Analysis based on a Kaggle Scrapped dataset

# %%
df_etf_prices, df_etfs = load_etfs_data()
# Out:
# Loading ETFs data ...

# %% [markdown]
# ## Performance by 10 years annualized return down to SPY

# %%
window_str = "10years"

df_display = df_etfs.sort_values(by=f"fund_return_{window_str}", ascending=False)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)

df_display.head(spy_loc + 1)[
    list(df_etfs.columns[0:1])
    +
    # list(df_etfs.columns[5:7])
    # +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        #'fund_return_1year',
        "fund_return_3years",
        "fund_alpha_3years",
        #'fund_return_5years',
        #'fund_alpha_5years',
        "fund_return_10years",
        "fund_alpha_10years",
        f"fund_stdev_{window_str}",
        f"fund_sharpe_ratio_{window_str}",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_7a89f th {
#   max-width: 80px;
# }
# #T_7a89f th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_7a89f thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_7a89f_row0_col5, #T_7a89f_row1_col12, #T_7a89f_row32_col6, #T_7a89f_row57_col8 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col6, #T_7a89f_row4_col6, #T_7a89f_row5_col6, #T_7a89f_row6_col6, #T_7a89f_row9_col6, #T_7a89f_row10_col6, #T_7a89f_row11_col6, #T_7a89f_row13_col6, #T_7a89f_row16_col6, #T_7a89f_row17_col6, #T_7a89f_row18_col6, #T_7a89f_row23_col6, #T_7a89f_row25_col6, #T_7a89f_row33_col6, #T_7a89f_row36_col6, #T_7a89f_row38_col6, #T_7a89f_row44_col12, #T_7a89f_row45_col12, #T_7a89f_row53_col6 {
#   background-color: #2c2c2c;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col7, #T_7a89f_row29_col10 {
#   background-color: #1c1c1c;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col8, #T_7a89f_row27_col12 {
#   background-color: #606060;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col9, #T_7a89f_row1_col7, #T_7a89f_row3_col11, #T_7a89f_row15_col10, #T_7a89f_row15_col11, #T_7a89f_row15_col12, #T_7a89f_row19_col10, #T_7a89f_row20_col12, #T_7a89f_row41_col6, #T_7a89f_row43_col8, #T_7a89f_row66_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col10 {
#   background-color: #1d1d1d;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col11 {
#   background-color: #717171;
#   color: #f1f1f1;
# }
# #T_7a89f_row0_col12, #T_7a89f_row24_col12 {
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_7a89f_row1_col5, #T_7a89f_row10_col8, #T_7a89f_row52_col7 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_7a89f_row1_col6, #T_7a89f_row2_col7, #T_7a89f_row12_col6, #T_7a89f_row52_col10 {
#   background-color: #212121;
#   color: #f1f1f1;
# }
# #T_7a89f_row1_col8 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_7a89f_row1_col9, #T_7a89f_row19_col12, #T_7a89f_row21_col6 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_7a89f_row1_col10, #T_7a89f_row1_col11 {
#   background-color: #222222;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col5, #T_7a89f_row12_col5, #T_7a89f_row23_col8, #T_7a89f_row40_col5, #T_7a89f_row44_col11, #T_7a89f_row45_col11, #T_7a89f_row53_col9, #T_7a89f_row54_col9, #T_7a89f_row54_col11, #T_7a89f_row55_col11, #T_7a89f_row56_col11, #T_7a89f_row60_col11, #T_7a89f_row61_col11, #T_7a89f_row62_col11, #T_7a89f_row66_col11 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_7a89f_row2_col6, #T_7a89f_row7_col6 {
#   background-color: #1b1b1b;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col8, #T_7a89f_row6_col7, #T_7a89f_row55_col12 {
#   background-color: #5d5d5d;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col9, #T_7a89f_row30_col12 {
#   background-color: #272727;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col10 {
#   background-color: #3c3c3c;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col11, #T_7a89f_row20_col8, #T_7a89f_row60_col10, #T_7a89f_row66_col10 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_7a89f_row2_col12, #T_7a89f_row59_col10, #T_7a89f_row60_col12, #T_7a89f_row63_col10, #T_7a89f_row64_col10 {
#   background-color: #6f6f6f;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col5, #T_7a89f_row5_col5, #T_7a89f_row6_col5, #T_7a89f_row7_col5, #T_7a89f_row9_col5, #T_7a89f_row11_col5, #T_7a89f_row13_col5, #T_7a89f_row16_col5, #T_7a89f_row17_col5, #T_7a89f_row18_col5, #T_7a89f_row19_col5, #T_7a89f_row21_col5, #T_7a89f_row22_col5, #T_7a89f_row23_col5, #T_7a89f_row25_col5, #T_7a89f_row26_col5, #T_7a89f_row27_col5, #T_7a89f_row28_col5, #T_7a89f_row31_col5, #T_7a89f_row32_col5, #T_7a89f_row33_col5, #T_7a89f_row34_col5, #T_7a89f_row35_col5, #T_7a89f_row36_col5, #T_7a89f_row36_col7, #T_7a89f_row36_col8, #T_7a89f_row36_col12, #T_7a89f_row37_col5, #T_7a89f_row38_col5, #T_7a89f_row39_col5, #T_7a89f_row41_col7, #T_7a89f_row41_col8, #T_7a89f_row41_col10, #T_7a89f_row41_col12, #T_7a89f_row42_col5, #T_7a89f_row43_col5, #T_7a89f_row44_col5, #T_7a89f_row46_col5, #T_7a89f_row47_col5, #T_7a89f_row49_col5, #T_7a89f_row50_col5, #T_7a89f_row51_col5, #T_7a89f_row52_col5, #T_7a89f_row53_col5, #T_7a89f_row54_col5, #T_7a89f_row55_col5, #T_7a89f_row56_col5, #T_7a89f_row56_col6, #T_7a89f_row56_col9, #T_7a89f_row57_col9, #T_7a89f_row57_col11, #T_7a89f_row58_col5, #T_7a89f_row58_col9, #T_7a89f_row59_col5, #T_7a89f_row59_col9, #T_7a89f_row60_col6, #T_7a89f_row60_col9, #T_7a89f_row61_col6, #T_7a89f_row61_col9, #T_7a89f_row62_col6, #T_7a89f_row62_col9, #T_7a89f_row63_col5, #T_7a89f_row63_col9, #T_7a89f_row64_col9, #T_7a89f_row65_col6, #T_7a89f_row65_col9, #T_7a89f_row66_col9 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_7a89f_row3_col6 {
#   background-color: #1e1e1e;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col7, #T_7a89f_row20_col5, #T_7a89f_row39_col8 {
#   background-color: #797979;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col8 {
#   background-color: #141414;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col9, #T_7a89f_row21_col11 {
#   background-color: #6e6e6e;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col10 {
#   background-color: #161616;
#   color: #f1f1f1;
# }
# #T_7a89f_row3_col12, #T_7a89f_row29_col12 {
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_7a89f_row4_col5, #T_7a89f_row15_col5, #T_7a89f_row21_col7, #T_7a89f_row30_col11, #T_7a89f_row37_col11, #T_7a89f_row38_col12, #T_7a89f_row49_col9, #T_7a89f_row53_col7, #T_7a89f_row63_col6 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_7a89f_row4_col7, #T_7a89f_row4_col8 {
#   background-color: #626262;
#   color: #f1f1f1;
# }
# #T_7a89f_row4_col9, #T_7a89f_row27_col8 {
#   background-color: #757575;
#   color: #f1f1f1;
# }
# #T_7a89f_row4_col10, #T_7a89f_row32_col10 {
#   background-color: #232323;
#   color: #f1f1f1;
# }
# #T_7a89f_row4_col11, #T_7a89f_row25_col10 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_7a89f_row4_col12, #T_7a89f_row15_col8, #T_7a89f_row20_col10, #T_7a89f_row40_col12 {
#   background-color: #363636;
#   color: #f1f1f1;
# }
# #T_7a89f_row5_col7 {
#   background-color: #434343;
#   color: #f1f1f1;
# }
# #T_7a89f_row5_col8, #T_7a89f_row43_col7 {
#   background-color: #4e4e4e;
#   color: #f1f1f1;
# }
# #T_7a89f_row5_col9, #T_7a89f_row28_col8, #T_7a89f_row40_col8 {
#   background-color: #7b7b7b;
#   color: #f1f1f1;
# }
# #T_7a89f_row5_col10, #T_7a89f_row6_col10, #T_7a89f_row46_col10 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_7a89f_row5_col11, #T_7a89f_row14_col7 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_7a89f_row5_col12, #T_7a89f_row54_col12 {
#   background-color: #585858;
#   color: #f1f1f1;
# }
# #T_7a89f_row6_col8, #T_7a89f_row32_col8 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_7a89f_row6_col9, #T_7a89f_row44_col8, #T_7a89f_row45_col8, #T_7a89f_row58_col8 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# #T_7a89f_row6_col11, #T_7a89f_row7_col8 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_7a89f_row6_col12, #T_7a89f_row7_col9 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_7a89f_row7_col7, #T_7a89f_row8_col10 {
#   background-color: #aeaeae;
#   color: #000000;
# }
# #T_7a89f_row7_col10 {
#   background-color: #4d4d4d;
#   color: #f1f1f1;
# }
# #T_7a89f_row7_col11 {
#   background-color: #a0a0a0;
#   color: #f1f1f1;
# }
# #T_7a89f_row7_col12, #T_7a89f_row32_col12, #T_7a89f_row50_col12, #T_7a89f_row55_col8 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_7a89f_row8_col5, #T_7a89f_row23_col10, #T_7a89f_row25_col7, #T_7a89f_row27_col11, #T_7a89f_row37_col9, #T_7a89f_row38_col9, #T_7a89f_row39_col9, #T_7a89f_row40_col9 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_7a89f_row8_col6 {
#   background-color: #333333;
#   color: #f1f1f1;
# }
# #T_7a89f_row8_col7 {
#   background-color: #a4a4a4;
#   color: #f1f1f1;
# }
# #T_7a89f_row8_col8, #T_7a89f_row10_col10 {
#   background-color: #c3c3c3;
#   color: #000000;
# }
# #T_7a89f_row8_col9, #T_7a89f_row17_col10, #T_7a89f_row18_col8 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_7a89f_row8_col11, #T_7a89f_row60_col8 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# #T_7a89f_row8_col12 {
#   background-color: #aaaaaa;
#   color: #f1f1f1;
# }
# #T_7a89f_row9_col7, #T_7a89f_row16_col10 {
#   background-color: #bdbdbd;
#   color: #000000;
# }
# #T_7a89f_row9_col8 {
#   backgrou

# %%
spy_loc + 1
# Out:
# 67

# %% [markdown]
# As of 2021, there were 67 ETFs in this datasets that were above or at SPY. We can round this up to the top 100 symbols and include them in our multivariate analysis.

# %% [markdown]
# ## Some metrics sorted by average 3 month volume
# This shows the highest volume ETFs

# %%
df_display = df_etfs.sort_values(by="avg_vol_3month", ascending=False)

df_display.head(20)[
    list(df_etfs.columns[0:1])
    +
    # list(df_etfs.columns[5:7])
    # +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        "fund_return_3years",
        "fund_alpha_3years",
        "fund_return_10years",
        "fund_alpha_10years",
        f"fund_stdev_3years",
        f"fund_sharpe_ratio_3years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_92a40 th {
#   max-width: 80px;
# }
# #T_92a40 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_92a40 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_92a40_row0_col5, #T_92a40_row1_col12, #T_92a40_row2_col6, #T_92a40_row2_col9, #T_92a40_row2_col10, #T_92a40_row2_col11, #T_92a40_row3_col9, #T_92a40_row3_col10, #T_92a40_row5_col9, #T_92a40_row5_col10, #T_92a40_row14_col7, #T_92a40_row15_col9, #T_92a40_row15_col10, #T_92a40_row18_col8, #T_92a40_row18_col9, #T_92a40_row18_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_92a40_row0_col6, #T_92a40_row10_col11, #T_92a40_row13_col7, #T_92a40_row13_col8, #T_92a40_row13_col9, #T_92a40_row13_col10, #T_92a40_row13_col12, #T_92a40_row19_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_92a40_row0_col7 {
#   background-color: #676767;
#   color: #f1f1f1;
# }
# #T_92a40_row0_col8, #T_92a40_row4_col8, #T_92a40_row7_col12 {
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_92a40_row0_col9, #T_92a40_row6_col8 {
#   background-color: #646464;
#   color: #f1f1f1;
# }
# #T_92a40_row0_col10 {
#   background-color: #272727;
#   color: #f1f1f1;
# }
# #T_92a40_row0_col11, #T_92a40_row4_col11 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_92a40_row0_col12 {
#   background-color: #1e1e1e;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col5 {
#   background-color: #8a8a8a;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col6, #T_92a40_row8_col11, #T_92a40_row11_col11 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_92a40_row1_col7, #T_92a40_row11_col8 {
#   background-color: #565656;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col8 {
#   background-color: #3f3f3f;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col9, #T_92a40_row12_col10 {
#   background-color: #555555;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col10 {
#   background-color: #0a0a0a;
#   color: #f1f1f1;
# }
# #T_92a40_row1_col11, #T_92a40_row13_col5 {
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_92a40_row2_col5 {
#   background-color: #919191;
#   color: #f1f1f1;
# }
# #T_92a40_row2_col7 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_92a40_row2_col8 {
#   background-color: #9d9d9d;
#   color: #f1f1f1;
# }
# #T_92a40_row2_col12, #T_92a40_row5_col12 {
#   background-color: #8e8e8e;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col5 {
#   background-color: #a0a0a0;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col6 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col7 {
#   background-color: #0c0c0c;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col8 {
#   background-color: #383838;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col11 {
#   background-color: #a9a9a9;
#   color: #f1f1f1;
# }
# #T_92a40_row3_col12 {
#   background-color: #141414;
#   color: #f1f1f1;
# }
# #T_92a40_row4_col5, #T_92a40_row17_col11 {
#   background-color: #a8a8a8;
#   color: #f1f1f1;
# }
# #T_92a40_row4_col6 {
#   background-color: #bdbdbd;
#   color: #000000;
# }
# #T_92a40_row4_col7, #T_92a40_row11_col9 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_92a40_row4_col9 {
#   background-color: #7b7b7b;
#   color: #f1f1f1;
# }
# #T_92a40_row4_col10 {
#   background-color: #353535;
#   color: #f1f1f1;
# }
# #T_92a40_row4_col12 {
#   background-color: #505050;
#   color: #f1f1f1;
# }
# #T_92a40_row5_col5, #T_92a40_row18_col7 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_92a40_row5_col6 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_92a40_row5_col7 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_92a40_row5_col8, #T_92a40_row8_col7 {
#   background-color: #858585;
#   color: #f1f1f1;
# }
# #T_92a40_row5_col11 {
#   background-color: #6f6f6f;
#   color: #f1f1f1;
# }
# #T_92a40_row6_col5, #T_92a40_row12_col7 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_92a40_row6_col6, #T_92a40_row14_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_92a40_row6_col7, #T_92a40_row8_col12 {
#   background-color: #707070;
#   color: #f1f1f1;
# }
# #T_92a40_row6_col9 {
#   background-color: #696969;
#   color: #f1f1f1;
# }
# #T_92a40_row6_col10 {
#   background-color: #434343;
#   color: #f1f1f1;
# }
# #T_92a40_row6_col11 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_92a40_row6_col12, #T_92a40_row9_col12 {
#   background-color: #474747;
#   color: #f1f1f1;
# }
# #T_92a40_row7_col5 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_92a40_row7_col6, #T_92a40_row17_col12, #T_92a40_row19_col11 {
#   background-color: #cacaca;
#   color: #000000;
# }
# #T_92a40_row7_col7, #T_92a40_row19_col10 {
#   background-color: #757575;
#   color: #f1f1f1;
# }
# #T_92a40_row7_col8, #T_92a40_row10_col8 {
#   background-color: #4d4d4d;
#   color: #f1f1f1;
# }
# #T_92a40_row7_col9, #T_92a40_row9_col9 {
#   background-color: #8d8d8d;
#   color: #f1f1f1;
# }
# #T_92a40_row7_col10, #T_92a40_row11_col12 {
#   background-color: #525252;
#   color: #f1f1f1;
# }
# #T_92a40_row7_col11, #T_92a40_row9_col5 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_92a40_row8_col5 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_92a40_row8_col6 {
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_92a40_row8_col8 {
#   background-color: #5b5b5b;
#   color: #f1f1f1;
# }
# #T_92a40_row8_col9 {
#   background-color: #7e7e7e;
#   color: #f1f1f1;
# }
# #T_92a40_row8_col10, #T_92a40_row9_col8 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_92a40_row9_col6 {
#   background-color: #d7d7d7;
#   color: #000000;
# }
# #T_92a40_row9_col7, #T_92a40_row18_col11 {
#   background-color: #6a6a6a;
#   color: #f1f1f1;
# }
# #T_92a40_row9_col10 {
#   background-color: #080808;
#   color: #f1f1f1;
# }
# #T_92a40_row9_col11, #T_92a40_row16_col9 {
#   background-color: #e3e3e3;
#   color: #000000;
# }
# #T_92a40_row10_col5 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_92a40_row10_col6 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_92a40_row10_col7 {
#   background-color: #7d7d7d;
#   color: #f1f1f1;
# }
# #T_92a40_row10_col9, #T_92a40_row11_col7 {
#   background-color: #797979;
#   color: #f1f1f1;
# }
# #T_92a40_row10_col10 {
#   background-color: #131313;
#   color: #f1f1f1;
# }
# #T_92a40_row10_col12 {
#   background-color: #414141;
#   color: #f1f1f1;
# }
# #T_92a40_row11_col5, #T_92a40_row12_col12 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_92a40_row11_col6 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_92a40_row11_col10 {
#   background-color: #232323;
#   color: #f1f1f1;
# }
# #T_92a40_row12_col5, #T_92a40_row17_col7, #T_92a40_row17_col9 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_92a40_row12_col6 {
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_92a40_row12_col8 {
#   background-color: #6e6e6e;
#   color: #f1f1f1;
# }
# #T_92a40_row12_col9 {
#   background-color: #cbcbcb;
#   color: #000000;
# }
# #T_92a40_row12_col11, #T_92a40_row16_col7 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_92a40_row13_col6 {
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_92a40_row13_col11 {
#   background-color: #9a9a9a;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col6 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col8 {
#   background-color: #1f1f1f;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col9 {
#   background-color: #070707;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col10 {
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col11 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_92a40_row14_col12 {
#   background-color: #111111;
#   color: #f1f1f1;
# }
# #T_92a40_row15_col5 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_92a40_row15_col6 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_92a40_row15_col7 {
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_92a40_row15_col8 {
#   background-color: #535353;
#   color: #f1f1f1;
# }
# #T_92a40_row15_col11 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_92a40_row15_col12 {
#   background-color: #5e5e5e;
#   color: #f1f1f1;
# }
# #T_92a40_row16_col5, #T_92a40_row17_col5 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_92a40_row16_col6 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_92a40_row16_col8, #T_92a40_row19_col12 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_92a40_row16_col10 {
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_92a40_row16_col11 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_92a40_row16_col12 {
#   backgroun

# %% [markdown]
# ## Performance 10y focused
# - High sharpe ratio
# - Returns >= SPY
# - Long term STD close to SPY (< 16%)
# - Avg_volum_3months > 1%SPY

# %%
window_str = "10years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)
# df_display = df_display.head(spy_loc + 1).sort_values(
#     by=['avg_vol_3month'], ascending=False
# )
df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]

df_display = df_display[df_display[f"fund_stdev_10years"] < 16]


df_display[
    list(df_etfs.columns[0:1])
    +
    # list(df_etfs.columns[5:7])
    # +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        #'fund_return_1year',
        "fund_return_3years",
        "fund_return_5years",
        "fund_return_10years",
        f"fund_stdev_3years",
        f"fund_stdev_5years",
        f"fund_stdev_10years",
        f"fund_sharpe_ratio_3years",
        f"fund_sharpe_ratio_5years",
        f"fund_sharpe_ratio_10years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_75263 th {
#   max-width: 80px;
# }
# #T_75263 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_75263 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_75263_row0_col5, #T_75263_row3_col14 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_75263_row0_col6 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_75263_row0_col7, #T_75263_row0_col8, #T_75263_row0_col9, #T_75263_row0_col10, #T_75263_row0_col11, #T_75263_row0_col12, #T_75263_row0_col13, #T_75263_row0_col14, #T_75263_row0_col15, #T_75263_row1_col6, #T_75263_row4_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_75263_row1_col5, #T_75263_row1_col10, #T_75263_row4_col6, #T_75263_row4_col7, #T_75263_row4_col8, #T_75263_row4_col9, #T_75263_row4_col11, #T_75263_row4_col12, #T_75263_row4_col13, #T_75263_row4_col14, #T_75263_row4_col15 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_75263_row1_col7 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_75263_row1_col8 {
#   background-color: #aaaaaa;
#   color: #f1f1f1;
# }
# #T_75263_row1_col9 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_75263_row1_col11 {
#   background-color: #8e8e8e;
#   color: #f1f1f1;
# }
# #T_75263_row1_col12 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_75263_row1_col13, #T_75263_row2_col13 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_75263_row1_col14 {
#   background-color: #a5a5a5;
#   color: #f1f1f1;
# }
# #T_75263_row1_col15 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_75263_row2_col5, #T_75263_row3_col5 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_75263_row2_col6 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_75263_row2_col7, #T_75263_row3_col9 {
#   background-color: #a7a7a7;
#   color: #f1f1f1;
# }
# #T_75263_row2_col8 {
#   background-color: #b8b8b8;
#   color: #000000;
# }
# #T_75263_row2_col9 {
#   background-color: #c0c0c0;
#   color: #000000;
# }
# #T_75263_row2_col10 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_75263_row2_col11 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_75263_row2_col12 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_75263_row2_col14 {
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_75263_row2_col15 {
#   background-color: #7e7e7e;
#   color: #f1f1f1;
# }
# #T_75263_row3_col6 {
#   background-color: #cfcfcf;
#   color: #000000;
# }
# #T_75263_row3_col7 {
#   background-color: #6c6c6c;
#   color: #f1f1f1;
# }
# #T_75263_row3_col8 {
#   background-color: #848484;
#   color: #f1f1f1;
# }
# #T_75263_row3_col10 {
#   background-color: #404040;
#   color: #f1f1f1;
# }
# #T_75263_row3_col11 {
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_75263_row3_col12 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_75263_row3_col13 {
#   background-color: #707070;
#   color: #f1f1f1;
# }
# #T_75263_row3_col15 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_75263_row4_col10 {
#   background-color: #dddddd;
#   color: #000000;
# }
# </style>
# <table id="T_75263">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75263_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_75263_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_75263_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_75263_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_75263_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_75263_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_75263_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_75263_level0_col7" class="col_heading level0 col7" >fund_return_3years</th>
#       <th id="T_75263_level0_col8" class="col_heading level0 col8" >fund_return_5years</th>
#       <th id="T_75263_level0_col9" class="col_heading level0 col9" >fund_return_10years</th>
#       <th id="T_75263_level0_col10" class="col_heading level0 col10" >fund_stdev_3years</th>
#       <th id="T_75263_level0_col11" class="col_heading level0 col11" >fund_stdev_5years</th>
#       <th id="T_75263_level0_col12" class="col_heading level0 col12" >fund_stdev_10years</th>
#       <th id="T_75263_level0_col13" class="col_heading level0 col13" >fund_sharpe_ratio_3years</th>
#       <th id="T_75263_level0_col14" class="col_heading level0 col14" >fund_sharpe_ratio_5years</th>
#       <th id="T_75263_level0_col15" class="col_heading level0 col15" >fund_sharpe_ratio_10years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75263_level0_row0" class="row_heading level0 row0" >1498</th>
#       <td id="T_75263_row0_col0" class="data row0 col0" >QQQ</td>
#       <td id="T_75263_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_75263_row0_col2" class="data row0 col2" >1999-03-10</td>
#       <td id="T_75263_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_75263_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_75263_row0_col5" class="data row0 col5" >46374673</td>
#       <td id="T_75263_row0_col6" class="data row0 col6" >0.002000</td>
#       <td id="T_75263_row0_col7" class="data row0 col7" >0.282900</td>
#       <td id="T_75263_row0_col8" class="data row0 col8" >0.279800</td>
#       <td id="T_75263_row0_col9" class="data row0 col9" >0.212500</td>
#       <td id="T_75263_row0_col10" class="data row0 col10" >20.240000</td>
#       <td id="T_75263_row0_col11" class="data row0 col11" >16.890000</td>
#       <td id="T_75263_row0_col12" class="data row0 col12" >15.680000</td>
#       <td id="T_75263_row0_col13" class="data row0 col13" >1.280000</td>
#       <td id="T_75263_row0_col14" class="data row0 col14" >1.480000</td>
#       <td id="T_75263_row0_col15" class="data row0 col15" >1.280000</td>
#     </tr>
#     <tr>
#       <th id="T_75263_level0_row1" class="row_heading level0 row1" >2215</th>
#       <td id="T_75263_row1_col0" class="data row1 col0" >IHI</td>
#       <td id="T_75263_row1_col1" class="data row1 col1" >NYSEArca</td>
#       <td id="T_75263_row1_col2" class="data row1 col2" >2006-05-01</td>
#       <td id="T_75263_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_75263_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_75263_row1_col5" class="data row1 col5" >939369</td>
#       <td id="T_75263_row1_col6" class="data row1 col6" >0.004200</td>
#       <td id="T_75263_row1_col7" class="data row1 col7" >0.220000</td>
#       <td id="T_75263_row1_col8" class="data row1 col8" >0.220700</td>
#       <td id="T_75263_row1_col9" class="data row1 col9" >0.189500</td>
#       <td id="T_75263_row1_col10" class="data row1 col10" >17.970000</td>
#       <td id="T_75263_row1_col11" class="data row1 col11" >15.980000</td>
#       <td id="T_75263_row1_col12" class="data row1 col12" >15.070000</td>
#       <td id="T_75263_row1_col13" class="data row1 col13" >1.130000</td>
#       <td id="T_75263_row1_col14" class="data row1 col14" >1.260000</td>
#       <td id="T_75263_row1_col15" class="data row1 col15" >1.190000</td>
#     </tr>
#     <tr>
#       <th id="T_75263_level0_row2" class="row_heading level0 row2" >2240</th>
#       <td id="T_75263_row2_col0" class="data row2 col0" >IVW</td>
#       <td id="T_75263_row2_col1" class="data row2 col1" >NYSEArca</td>
#       <td id="T_75263_row2_col2" class="data row2 col2" >2000-05-22</td>
#       <td id="T_75263_row2_col3" class="data row2 col3" >Growth</td>
#       <td id="T_75263_row2_col4" class="data row2 col4" >Large</td>
#       <td id="T_75263_row2_col5" class="data row2 col5" >1835620</td>
#       <td id="T_75263_row2_col6" class="data row2 col6" >0.001800</td>
#       <td id="T_75263_row2_col7" class="data row2 col7" >0.228800</td>
#       <td id="T_75263_row2_col8" class="data row2 col8" >0.216100</td>
#       <td id="T_75263_row2_col9" class="data row2 col9" >0.170800</td>
#       <td id="T_75263_row2_col10" class="data row2 col10" >18.730000</td>
#       <td id="T_75263_row2_col11" class="data row2 col11" >15.290000</td>
#       <td id="T_75263_row2_col12"

# %% [markdown]
# ## Performance 5y focused
# - High sharpe ratio
# - Sharpe ratio > 1.1
# - 5year STD  < 22%
# - Avg_volum_3months > 1%SPY

# %%
window_str = "5years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)
# df_display = df_display.head(spy_loc + 1).sort_values(
#     by=['avg_vol_3month'], ascending=False
# )
df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]


df_display = df_display[df_display["fund_sharpe_ratio_3years"] >= 1.1]

df_display = df_display[df_display[f"fund_stdev_5years"] < 22]
# df_display = df_display[df_display[f'fund_return_3years'] > 0.1 ]


df_display[
    list(df_etfs.columns[0:1])
    +
    # list(df_etfs.columns[5:7])
    # +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        #'fund_return_1year',
        "fund_return_3years",
        "fund_return_5years",
        "fund_return_10years",
        f"fund_stdev_3years",
        f"fund_stdev_5years",
        f"fund_stdev_10years",
        f"fund_sharpe_ratio_3years",
        f"fund_sharpe_ratio_5years",
        f"fund_sharpe_ratio_10years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_4c362 th {
#   max-width: 80px;
# }
# #T_4c362 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_4c362 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_4c362_row0_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_4c362_row0_col6 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_4c362_row0_col7, #T_4c362_row0_col8, #T_4c362_row0_col9, #T_4c362_row0_col10, #T_4c362_row0_col11, #T_4c362_row0_col12, #T_4c362_row0_col13, #T_4c362_row0_col14, #T_4c362_row0_col15, #T_4c362_row1_col6, #T_4c362_row1_col12, #T_4c362_row2_col5, #T_4c362_row2_col15 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col5, #T_4c362_row4_col6, #T_4c362_row5_col5, #T_4c362_row5_col7, #T_4c362_row5_col10, #T_4c362_row6_col5, #T_4c362_row6_col8, #T_4c362_row6_col9, #T_4c362_row6_col11, #T_4c362_row6_col12, #T_4c362_row6_col13, #T_4c362_row6_col14, #T_4c362_row6_col15 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4c362_row1_col7 {
#   background-color: #adadad;
#   color: #000000;
# }
# #T_4c362_row1_col8 {
#   background-color: #797979;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col9 {
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col10, #T_4c362_row2_col13 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col11 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col13 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_4c362_row1_col14 {
#   background-color: #242424;
#   color: #f1f1f1;
# }
# #T_4c362_row1_col15 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_4c362_row2_col6, #T_4c362_row6_col10 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_4c362_row2_col7 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_4c362_row2_col8 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_4c362_row2_col9 {
#   background-color: #555555;
#   color: #f1f1f1;
# }
# #T_4c362_row2_col10 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_4c362_row2_col11 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_4c362_row2_col12 {
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_4c362_row2_col14 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_4c362_row3_col5, #T_4c362_row4_col5, #T_4c362_row6_col7 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_4c362_row3_col6, #T_4c362_row4_col13, #T_4c362_row5_col13 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_4c362_row3_col7 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_4c362_row3_col8 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_4c362_row3_col9 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_4c362_row3_col10, #T_4c362_row4_col14 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_4c362_row3_col11 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_4c362_row3_col12 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_4c362_row3_col13 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_4c362_row3_col14 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_4c362_row3_col15 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_4c362_row4_col7 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_4c362_row4_col8 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_4c362_row4_col9 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_4c362_row4_col10 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_4c362_row4_col11 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_4c362_row4_col12 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_4c362_row4_col15 {
#   background-color: #686868;
#   color: #f1f1f1;
# }
# #T_4c362_row5_col6 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_4c362_row5_col8 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_4c362_row5_col9 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_4c362_row5_col11, #T_4c362_row5_col14 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_4c362_row5_col12 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_4c362_row5_col15 {
#   background-color: #5f5f5f;
#   color: #f1f1f1;
# }
# #T_4c362_row6_col6 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c362">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c362_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_4c362_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_4c362_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_4c362_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_4c362_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_4c362_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_4c362_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_4c362_level0_col7" class="col_heading level0 col7" >fund_return_3years</th>
#       <th id="T_4c362_level0_col8" class="col_heading level0 col8" >fund_return_5years</th>
#       <th id="T_4c362_level0_col9" class="col_heading level0 col9" >fund_return_10years</th>
#       <th id="T_4c362_level0_col10" class="col_heading level0 col10" >fund_stdev_3years</th>
#       <th id="T_4c362_level0_col11" class="col_heading level0 col11" >fund_stdev_5years</th>
#       <th id="T_4c362_level0_col12" class="col_heading level0 col12" >fund_stdev_10years</th>
#       <th id="T_4c362_level0_col13" class="col_heading level0 col13" >fund_sharpe_ratio_3years</th>
#       <th id="T_4c362_level0_col14" class="col_heading level0 col14" >fund_sharpe_ratio_5years</th>
#       <th id="T_4c362_level0_col15" class="col_heading level0 col15" >fund_sharpe_ratio_10years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c362_level0_row0" class="row_heading level0 row0" >1697</th>
#       <td id="T_4c362_row0_col0" class="data row0 col0" >SMH</td>
#       <td id="T_4c362_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_4c362_row0_col2" class="data row0 col2" >2011-12-20</td>
#       <td id="T_4c362_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_4c362_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_4c362_row0_col5" class="data row0 col5" >3470350</td>
#       <td id="T_4c362_row0_col6" class="data row0 col6" >0.003500</td>
#       <td id="T_4c362_row0_col7" class="data row0 col7" >0.385700</td>
#       <td id="T_4c362_row0_col8" class="data row0 col8" >0.374100</td>
#       <td id="T_4c362_row0_col9" class="data row0 col9" >0.242700</td>
#       <td id="T_4c362_row0_col10" class="data row0 col10" >24.660000</td>
#       <td id="T_4c362_row0_col11" class="data row0 col11" >21.710000</td>
#       <td id="T_4c362_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_4c362_row0_col13" class="data row0 col13" >1.410000</td>
#       <td id="T_4c362_row0_col14" class="data row0 col14" >1.530000</td>
#       <td id="T_4c362_row0_col15" class="data row0 col15" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4c362_level0_row1" class="row_heading level0 row1" >2212</th>
#       <td id="T_4c362_row1_col0" class="data row1 col0" >IGV</td>
#       <td id="T_4c362_row1_col1" class="data row1 col1" >BATS</td>
#       <td id="T_4c362_row1_col2" class="data row1 col2" >2001-07-10</td>
#       <td id="T_4c362_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_4c362_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_4c362_row1_col5" class="data row1 col5" >1090682</td>
#       <td id="T_4c362_row1_col6" class="data row1 col6" >0.004600</td>
#       <td id="T_4c362_row1_col7" class="data row1 col7" >0.290900</td>
#       <td id="T_4c362_row1_col8" class="data row1 col8" >0.302200</td>
#       <td id="T_4c362_row1_col9" class="data row1 col9" >0.202900</td>
#       <td id="T_4c362_row1_col10" class="data row1 col10" >21.670000</td>
#       <td id="T_4c362_row1_col11" class="data row1 col11" >18.180000</td>
#       <td id="T_4c362_row1_col12" class="data row1 col12" >17.870000</td>
#       <td id="T_4c362_row1_col13" class="data row1 col13" >1.2

# %% [markdown]
# ## Performance 3y focused
# - High sharpe ratio
# - Returns >= 10%
# - Sharpe ratio > 1.1
# - Long term STD  < 30%
# - Avg_volum_3months > 1%SPY

# %%
window_str = "3years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)
# df_display = df_display.head(spy_loc + 1).sort_values(
#     by=['avg_vol_3month'], ascending=False
# )
df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]


df_display = df_display[df_display["fund_sharpe_ratio_3years"] >= 1.1]

df_display = df_display[df_display[f"fund_stdev_3years"] < 30]
df_display = df_display[df_display[f"fund_return_3years"] > 0.1]


df_display[
    list(df_etfs.columns[0:1])
    +
    # list(df_etfs.columns[5:7])
    # +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        #'fund_return_1year',
        "fund_return_3years",
        "fund_return_5years",
        "fund_return_10years",
        f"fund_stdev_3years",
        f"fund_stdev_5years",
        f"fund_stdev_10years",
        f"fund_sharpe_ratio_3years",
        f"fund_sharpe_ratio_5years",
        f"fund_sharpe_ratio_10years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_0a94d th {
#   max-width: 80px;
# }
# #T_0a94d th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_0a94d thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_0a94d_row0_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_0a94d_row0_col6 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_0a94d_row0_col7, #T_0a94d_row0_col8, #T_0a94d_row0_col9, #T_0a94d_row0_col10, #T_0a94d_row0_col11, #T_0a94d_row0_col12, #T_0a94d_row0_col13, #T_0a94d_row0_col14, #T_0a94d_row0_col15, #T_0a94d_row1_col5, #T_0a94d_row1_col15, #T_0a94d_row2_col6, #T_0a94d_row2_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0a94d_row1_col6, #T_0a94d_row6_col10 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_0a94d_row1_col7 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_0a94d_row1_col8 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_0a94d_row1_col9 {
#   background-color: #555555;
#   color: #f1f1f1;
# }
# #T_0a94d_row1_col10 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_0a94d_row1_col11 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_0a94d_row1_col12 {
#   background-color: #7c7c7c;
#   color: #f1f1f1;
# }
# #T_0a94d_row1_col13, #T_0a94d_row2_col10 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_0a94d_row1_col14 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_0a94d_row2_col5, #T_0a94d_row4_col5, #T_0a94d_row4_col7, #T_0a94d_row4_col10, #T_0a94d_row5_col6, #T_0a94d_row6_col5, #T_0a94d_row6_col8, #T_0a94d_row6_col9, #T_0a94d_row6_col11, #T_0a94d_row6_col12, #T_0a94d_row6_col13, #T_0a94d_row6_col14, #T_0a94d_row6_col15 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_0a94d_row2_col7 {
#   background-color: #adadad;
#   color: #000000;
# }
# #T_0a94d_row2_col8 {
#   background-color: #797979;
#   color: #f1f1f1;
# }
# #T_0a94d_row2_col9 {
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_0a94d_row2_col11 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_0a94d_row2_col13 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_0a94d_row2_col14 {
#   background-color: #242424;
#   color: #f1f1f1;
# }
# #T_0a94d_row2_col15 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_0a94d_row3_col5, #T_0a94d_row5_col5, #T_0a94d_row6_col7 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_0a94d_row3_col6, #T_0a94d_row4_col13, #T_0a94d_row5_col13 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_0a94d_row3_col7 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_0a94d_row3_col8 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_0a94d_row3_col9 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_0a94d_row3_col10, #T_0a94d_row5_col14 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_0a94d_row3_col11 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_0a94d_row3_col12 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_0a94d_row3_col13 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_0a94d_row3_col14 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_0a94d_row3_col15 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_0a94d_row4_col6 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_0a94d_row4_col8 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_0a94d_row4_col9 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_0a94d_row4_col11, #T_0a94d_row4_col14 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_0a94d_row4_col12 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_0a94d_row4_col15 {
#   background-color: #5f5f5f;
#   color: #f1f1f1;
# }
# #T_0a94d_row5_col7 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_0a94d_row5_col8 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_0a94d_row5_col9 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_0a94d_row5_col10 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_0a94d_row5_col11 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_0a94d_row5_col12 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_0a94d_row5_col15 {
#   background-color: #686868;
#   color: #f1f1f1;
# }
# #T_0a94d_row6_col6 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0a94d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a94d_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_0a94d_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_0a94d_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_0a94d_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_0a94d_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_0a94d_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_0a94d_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_0a94d_level0_col7" class="col_heading level0 col7" >fund_return_3years</th>
#       <th id="T_0a94d_level0_col8" class="col_heading level0 col8" >fund_return_5years</th>
#       <th id="T_0a94d_level0_col9" class="col_heading level0 col9" >fund_return_10years</th>
#       <th id="T_0a94d_level0_col10" class="col_heading level0 col10" >fund_stdev_3years</th>
#       <th id="T_0a94d_level0_col11" class="col_heading level0 col11" >fund_stdev_5years</th>
#       <th id="T_0a94d_level0_col12" class="col_heading level0 col12" >fund_stdev_10years</th>
#       <th id="T_0a94d_level0_col13" class="col_heading level0 col13" >fund_sharpe_ratio_3years</th>
#       <th id="T_0a94d_level0_col14" class="col_heading level0 col14" >fund_sharpe_ratio_5years</th>
#       <th id="T_0a94d_level0_col15" class="col_heading level0 col15" >fund_sharpe_ratio_10years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a94d_level0_row0" class="row_heading level0 row0" >1697</th>
#       <td id="T_0a94d_row0_col0" class="data row0 col0" >SMH</td>
#       <td id="T_0a94d_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_0a94d_row0_col2" class="data row0 col2" >2011-12-20</td>
#       <td id="T_0a94d_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_0a94d_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_0a94d_row0_col5" class="data row0 col5" >3470350</td>
#       <td id="T_0a94d_row0_col6" class="data row0 col6" >0.003500</td>
#       <td id="T_0a94d_row0_col7" class="data row0 col7" >0.385700</td>
#       <td id="T_0a94d_row0_col8" class="data row0 col8" >0.374100</td>
#       <td id="T_0a94d_row0_col9" class="data row0 col9" >0.242700</td>
#       <td id="T_0a94d_row0_col10" class="data row0 col10" >24.660000</td>
#       <td id="T_0a94d_row0_col11" class="data row0 col11" >21.710000</td>
#       <td id="T_0a94d_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_0a94d_row0_col13" class="data row0 col13" >1.410000</td>
#       <td id="T_0a94d_row0_col14" class="data row0 col14" >1.530000</td>
#       <td id="T_0a94d_row0_col15" class="data row0 col15" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0a94d_level0_row1" class="row_heading level0 row1" >1498</th>
#       <td id="T_0a94d_row1_col0" class="data row1 col0" >QQQ</td>
#       <td id="T_0a94d_row1_col1" class="data row1 col1" >NasdaqGM</td>
#       <td id="T_0a94d_row1_col2" class="data row1 col2" >1999-03-10</td>
#       <td id="T_0a94d_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_0a94d_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_0a94d_row1_col5" class="data row1 col5" >46374673</td>
#       <td id="T_0a94d_row1_col6" class="data row1 col6" >0.002000</td>
#       <td id="T_0a94d_row1_col7" class="data row1 col7" >0.282900</td>
#       <td id="T_0a94d_row1_col8" class="data row1 col8" >0.279800</td>
#       <td id="T_0a94d_row1_col9" class="data row1 col9" >0.212500</td>
#       <td id="T_0a94d_row1_col10" class="data row1 col10" >20.240000</td>
#       <td id="T_0a94d_row1_col11" class="data row1 col11" >16.890000</td>
#       <td id="T_0a94d_row1_col12" class="data row1 col12" >15.680000</td>
#       <td id="T_0a94d_row1_col13" class="data row1 col13"
