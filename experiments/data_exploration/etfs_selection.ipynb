# %%
# %load_ext autoreload
# %autoreload 2
from stock_prediction.data_exploration.kaggle_etfs import load_etfs_data
from stock_prediction.commons import PANDAS_STYLE_VERTICAL_COLNAMES

# %% [markdown]
# # Rough Performance Analysis based on a Kaggle Scrapped dataset
#
# The goal of this notebook is to short list a selection of tickers to include in our model building.
#
# Our goal is to develop a model that is able to predict how a given symbol will evolve, given its history/state and, possibly, information from the state of the market. Furthermore, we would like to bias towards a selection of symbols that perform well on long timescales. We envision an investor who is focusing on such symbols and wants to find a favourable time to invest on a few of them. Thus, below we look into an etfs dataset, for simplicity, and analyse a few metrics to short list the symbols we will work with.
#
# **Disclaimer:** This analysis was done on this slightly outdated dataset for convenience. Since the goal is only to short list a set of supported symbols it should not affect the overall quality of the solution we will develop later (also because we focus on selecting on long term stable symbols).

# %%
df_etf_prices, df_etfs = load_etfs_data()
# Out:
# Loading ETFs data ...

# %% [markdown]
# ## Performance by 10 years annualized return down to SPY
#
# The SP500 index is regarded as one of the indices that repesents well the overall state of the market. Peforming as well as SP500 is often regarded as a "safe" way to "go with the market" and various metrics will use it as a baseline to measure gains/losses against the market (e.g., the Sharpe Ratio).
#
# Thus, below we sort the available etf symbols on the dataset by 10 years annualized returns from the largest value down to SP500. We also display other metrics such as the 10 year volatility and sharpe ratio (which provides an indication of how significant the returns deviate relative to the market index given the volatility of the symbol).

# %%
window_str = "10years"

df_display = df_etfs.sort_values(by=f"fund_return_{window_str}", ascending=False)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)

df_display.head(spy_loc + 1)[
    list(df_etfs.columns[0:1])
    +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        "fund_return_10years",
        f"fund_stdev_{window_str}",
        f"fund_sharpe_ratio_{window_str}",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_16076 th {
#   max-width: 80px;
# }
# #T_16076 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_16076 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_16076_row0_col5, #T_16076_row1_col9, #T_16076_row32_col6 {
#   background-color: #8c8c8c;
#   color: #f1f1f1;
# }
# #T_16076_row0_col6, #T_16076_row4_col6, #T_16076_row5_col6, #T_16076_row6_col6, #T_16076_row9_col6, #T_16076_row10_col6, #T_16076_row11_col6, #T_16076_row13_col6, #T_16076_row16_col6, #T_16076_row17_col6, #T_16076_row18_col6, #T_16076_row23_col6, #T_16076_row25_col6, #T_16076_row33_col6, #T_16076_row36_col6, #T_16076_row38_col6, #T_16076_row44_col9, #T_16076_row45_col9, #T_16076_row53_col6 {
#   background-color: #2c2c2c;
#   color: #f1f1f1;
# }
# #T_16076_row0_col7, #T_16076_row3_col8, #T_16076_row15_col8, #T_16076_row15_col9, #T_16076_row20_col9, #T_16076_row41_col6, #T_16076_row66_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_16076_row0_col8 {
#   background-color: #717171;
#   color: #f1f1f1;
# }
# #T_16076_row0_col9, #T_16076_row24_col9 {
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_16076_row1_col5 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_16076_row1_col6, #T_16076_row12_col6 {
#   background-color: #212121;
#   color: #f1f1f1;
# }
# #T_16076_row1_col7, #T_16076_row19_col9, #T_16076_row21_col6 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_16076_row1_col8 {
#   background-color: #222222;
#   color: #f1f1f1;
# }
# #T_16076_row2_col5, #T_16076_row12_col5, #T_16076_row40_col5, #T_16076_row44_col8, #T_16076_row45_col8, #T_16076_row53_col7, #T_16076_row54_col7, #T_16076_row54_col8, #T_16076_row55_col8, #T_16076_row56_col8, #T_16076_row60_col8, #T_16076_row61_col8, #T_16076_row62_col8, #T_16076_row66_col8 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_16076_row2_col6, #T_16076_row7_col6 {
#   background-color: #1b1b1b;
#   color: #f1f1f1;
# }
# #T_16076_row2_col7, #T_16076_row30_col9 {
#   background-color: #272727;
#   color: #f1f1f1;
# }
# #T_16076_row2_col8 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_16076_row2_col9, #T_16076_row60_col9 {
#   background-color: #6f6f6f;
#   color: #f1f1f1;
# }
# #T_16076_row3_col5, #T_16076_row5_col5, #T_16076_row6_col5, #T_16076_row7_col5, #T_16076_row9_col5, #T_16076_row11_col5, #T_16076_row13_col5, #T_16076_row16_col5, #T_16076_row17_col5, #T_16076_row18_col5, #T_16076_row19_col5, #T_16076_row21_col5, #T_16076_row22_col5, #T_16076_row23_col5, #T_16076_row25_col5, #T_16076_row26_col5, #T_16076_row27_col5, #T_16076_row28_col5, #T_16076_row31_col5, #T_16076_row32_col5, #T_16076_row33_col5, #T_16076_row34_col5, #T_16076_row35_col5, #T_16076_row36_col5, #T_16076_row36_col9, #T_16076_row37_col5, #T_16076_row38_col5, #T_16076_row39_col5, #T_16076_row41_col9, #T_16076_row42_col5, #T_16076_row43_col5, #T_16076_row44_col5, #T_16076_row46_col5, #T_16076_row47_col5, #T_16076_row49_col5, #T_16076_row50_col5, #T_16076_row51_col5, #T_16076_row52_col5, #T_16076_row53_col5, #T_16076_row54_col5, #T_16076_row55_col5, #T_16076_row56_col5, #T_16076_row56_col6, #T_16076_row56_col7, #T_16076_row57_col7, #T_16076_row57_col8, #T_16076_row58_col5, #T_16076_row58_col7, #T_16076_row59_col5, #T_16076_row59_col7, #T_16076_row60_col6, #T_16076_row60_col7, #T_16076_row61_col6, #T_16076_row61_col7, #T_16076_row62_col6, #T_16076_row62_col7, #T_16076_row63_col5, #T_16076_row63_col7, #T_16076_row64_col7, #T_16076_row65_col6, #T_16076_row65_col7, #T_16076_row66_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_16076_row3_col6 {
#   background-color: #1e1e1e;
#   color: #f1f1f1;
# }
# #T_16076_row3_col7, #T_16076_row21_col8 {
#   background-color: #6e6e6e;
#   color: #f1f1f1;
# }
# #T_16076_row3_col9, #T_16076_row29_col9 {
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_16076_row4_col5, #T_16076_row15_col5, #T_16076_row30_col8, #T_16076_row37_col8, #T_16076_row38_col9, #T_16076_row49_col7, #T_16076_row63_col6 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_16076_row4_col7 {
#   background-color: #757575;
#   color: #f1f1f1;
# }
# #T_16076_row4_col8 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_16076_row4_col9, #T_16076_row40_col9 {
#   background-color: #363636;
#   color: #f1f1f1;
# }
# #T_16076_row5_col7 {
#   background-color: #7b7b7b;
#   color: #f1f1f1;
# }
# #T_16076_row5_col8 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_16076_row5_col9, #T_16076_row54_col9 {
#   background-color: #585858;
#   color: #f1f1f1;
# }
# #T_16076_row6_col7 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# #T_16076_row6_col8 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_16076_row6_col9, #T_16076_row7_col7 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_16076_row7_col8 {
#   background-color: #a0a0a0;
#   color: #f1f1f1;
# }
# #T_16076_row7_col9, #T_16076_row32_col9, #T_16076_row50_col9 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_16076_row8_col5, #T_16076_row27_col8, #T_16076_row37_col7, #T_16076_row38_col7, #T_16076_row39_col7, #T_16076_row40_col7 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_16076_row8_col6 {
#   background-color: #333333;
#   color: #f1f1f1;
# }
# #T_16076_row8_col7 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_16076_row8_col8 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# #T_16076_row8_col9 {
#   background-color: #aaaaaa;
#   color: #f1f1f1;
# }
# #T_16076_row9_col7 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_16076_row9_col8, #T_16076_row12_col7 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_16076_row9_col9, #T_16076_row65_col9 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_16076_row10_col5, #T_16076_row20_col8, #T_16076_row28_col8, #T_16076_row47_col7, #T_16076_row47_col8, #T_16076_row48_col7 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_16076_row10_col7 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_16076_row10_col8, #T_16076_row13_col8 {
#   background-color: #929292;
#   color: #f1f1f1;
# }
# #T_16076_row10_col9, #T_16076_row48_col9 {
#   background-color: #cdcdcd;
#   color: #000000;
# }
# #T_16076_row11_col7, #T_16076_row27_col6, #T_16076_row52_col6 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_16076_row11_col8, #T_16076_row15_col7, #T_16076_row16_col9, #T_16076_row53_col8 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_16076_row11_col9, #T_16076_row26_col9, #T_16076_row47_col9, #T_16076_row63_col9, #T_16076_row64_col9 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_16076_row12_col8 {
#   background-color: #676767;
#   color: #f1f1f1;
# }
# #T_16076_row12_col9 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_16076_row13_col7 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_16076_row13_col9 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_16076_row14_col5, #T_16076_row29_col5, #T_16076_row35_col6, #T_16076_row35_col8, #T_16076_row39_col8, #T_16076_row40_col8, #T_16076_row50_col7, #T_16076_row55_col6 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_16076_row14_col6 {
#   background-color: #3a3a3a;
#   color: #f1f1f1;
# }
# #T_16076_row14_col7 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_16076_row14_col8 {
#   background-color: #d7d7d7;
#   color: #000000;
# }
# #T_16076_row14_col9 {
#   background-color: #989898;
#   color: #f1f1f1;
# }
# #T_16076_row15_col6, #T_16076_row34_col6 {
#   background-color: #cfcfcf;
#   color: #000000;
# }
# #T_16076_row16_col7 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_16076_row16_col8 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_16076_row17_col7, #T_16076_row18_col7 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_16076_row17_col8 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_16076_row17_col9, #T_16076_row29_col6, #T_16076_row30_col6, #T_16076_row33_col8, #T_16076_row46_col9, #T_16076_row49_col6, #T_16076_row50_col6 {
#   background-color: #c0c0c0;
#   color: #000000;
# }
# #T_16076_row18_col8, #T_16076_row26_col6, #T_16076_row46_col6, #T_16076_row51_col6 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_16076_row18_col9 {
#   background-color: #b8b8b8;
#   color: #000000;
# }
# #T_1607

# %%
spy_loc + 1
# Out:
# 67

# %% [markdown]
# As of 2021, there were 67 ETFs in this datasets that were above or at SPY. We can round this up to the top 100 symbols and include them in our multivariate analysis.

# %%
df_display.head(100)[
    list(df_etfs.columns[0:1])]
# Out:
#      fund_symbol
# 1853        TQQQ
# 1710        SOXL
# 1816        TECL
# 1538        RETL
# 1482         QLD
# ...          ...
# 1370         PEZ
# 786          FYC
# 780          FXO
# 2140        EUSA
# 744         FTCS
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Scenarios for Investor
#
# In this section, we look into several criteria to select ETFs to invest in from the short list above. Some investors will be more focused on the long term other on the short term. Thus, for the sake creating some scenarios of a user of the app we short list a few symbols per scenario.

# %% [markdown]
# ### Performance 10y focused
# - High sharpe ratio
# - Returns >= SPY
# - Long term STD close to SPY (< 16%)
# - Avg_volum_3months > 1%SPY

# %%
window_str = "10years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)

df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]

df_display = df_display[df_display[f"fund_stdev_10years"] < 16]


df_display[
    list(df_etfs.columns[0:1])
    +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        "fund_return_10years",
        f"fund_stdev_10years",
        f"fund_sharpe_ratio_10years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_a1ca9 th {
#   max-width: 80px;
# }
# #T_a1ca9 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_a1ca9 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_a1ca9_row0_col5 {
#   background-color: #7a7a7a;
#   color: #f1f1f1;
# }
# #T_a1ca9_row0_col6 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_a1ca9_row0_col7, #T_a1ca9_row0_col8, #T_a1ca9_row0_col9, #T_a1ca9_row1_col6, #T_a1ca9_row4_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a1ca9_row1_col5, #T_a1ca9_row4_col6, #T_a1ca9_row4_col7, #T_a1ca9_row4_col8, #T_a1ca9_row4_col9 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_a1ca9_row1_col7 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_a1ca9_row1_col8 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_a1ca9_row1_col9 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_a1ca9_row2_col5, #T_a1ca9_row3_col5 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_a1ca9_row2_col6 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_a1ca9_row2_col7 {
#   background-color: #c0c0c0;
#   color: #000000;
# }
# #T_a1ca9_row2_col8 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_a1ca9_row2_col9 {
#   background-color: #7e7e7e;
#   color: #f1f1f1;
# }
# #T_a1ca9_row3_col6 {
#   background-color: #cfcfcf;
#   color: #000000;
# }
# #T_a1ca9_row3_col7 {
#   background-color: #a7a7a7;
#   color: #f1f1f1;
# }
# #T_a1ca9_row3_col8 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_a1ca9_row3_col9 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1ca9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1ca9_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_a1ca9_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_a1ca9_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_a1ca9_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_a1ca9_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_a1ca9_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_a1ca9_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_a1ca9_level0_col7" class="col_heading level0 col7" >fund_return_10years</th>
#       <th id="T_a1ca9_level0_col8" class="col_heading level0 col8" >fund_stdev_10years</th>
#       <th id="T_a1ca9_level0_col9" class="col_heading level0 col9" >fund_sharpe_ratio_10years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1ca9_level0_row0" class="row_heading level0 row0" >1498</th>
#       <td id="T_a1ca9_row0_col0" class="data row0 col0" >QQQ</td>
#       <td id="T_a1ca9_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_a1ca9_row0_col2" class="data row0 col2" >1999-03-10</td>
#       <td id="T_a1ca9_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_a1ca9_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_a1ca9_row0_col5" class="data row0 col5" >46374673</td>
#       <td id="T_a1ca9_row0_col6" class="data row0 col6" >0.002000</td>
#       <td id="T_a1ca9_row0_col7" class="data row0 col7" >0.212500</td>
#       <td id="T_a1ca9_row0_col8" class="data row0 col8" >15.680000</td>
#       <td id="T_a1ca9_row0_col9" class="data row0 col9" >1.280000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ca9_level0_row1" class="row_heading level0 row1" >2215</th>
#       <td id="T_a1ca9_row1_col0" class="data row1 col0" >IHI</td>
#       <td id="T_a1ca9_row1_col1" class="data row1 col1" >NYSEArca</td>
#       <td id="T_a1ca9_row1_col2" class="data row1 col2" >2006-05-01</td>
#       <td id="T_a1ca9_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_a1ca9_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_a1ca9_row1_col5" class="data row1 col5" >939369</td>
#       <td id="T_a1ca9_row1_col6" class="data row1 col6" >0.004200</td>
#       <td id="T_a1ca9_row1_col7" class="data row1 col7" >0.189500</td>
#       <td id="T_a1ca9_row1_col8" class="data row1 col8" >15.070000</td>
#       <td id="T_a1ca9_row1_col9" class="data row1 col9" >1.190000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ca9_level0_row2" class="row_heading level0 row2" >2240</th>
#       <td id="T_a1ca9_row2_col0" class="data row2 col0" >IVW</td>
#       <td id="T_a1ca9_row2_col1" class="data row2 col1" >NYSEArca</td>
#       <td id="T_a1ca9_row2_col2" class="data row2 col2" >2000-05-22</td>
#       <td id="T_a1ca9_row2_col3" class="data row2 col3" >Growth</td>
#       <td id="T_a1ca9_row2_col4" class="data row2 col4" >Large</td>
#       <td id="T_a1ca9_row2_col5" class="data row2 col5" >1835620</td>
#       <td id="T_a1ca9_row2_col6" class="data row2 col6" >0.001800</td>
#       <td id="T_a1ca9_row2_col7" class="data row2 col7" >0.170800</td>
#       <td id="T_a1ca9_row2_col8" class="data row2 col8" >13.770000</td>
#       <td id="T_a1ca9_row2_col9" class="data row2 col9" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ca9_level0_row3" class="row_heading level0 row3" >2244</th>
#       <td id="T_a1ca9_row3_col0" class="data row3 col0" >IWF</td>
#       <td id="T_a1ca9_row3_col1" class="data row3 col1" >NYSEArca</td>
#       <td id="T_a1ca9_row3_col2" class="data row3 col2" >2000-05-22</td>
#       <td id="T_a1ca9_row3_col3" class="data row3 col3" >Growth</td>
#       <td id="T_a1ca9_row3_col4" class="data row3 col4" >Large</td>
#       <td id="T_a1ca9_row3_col5" class="data row3 col5" >1707365</td>
#       <td id="T_a1ca9_row3_col6" class="data row3 col6" >0.001900</td>
#       <td id="T_a1ca9_row3_col7" class="data row3 col7" >0.176400</td>
#       <td id="T_a1ca9_row3_col8" class="data row3 col8" >14.430000</td>
#       <td id="T_a1ca9_row3_col9" class="data row3 col9" >1.160000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ca9_level0_row4" class="row_heading level0 row4" >1762</th>
#       <td id="T_a1ca9_row4_col0" class="data row4 col0" >SPY</td>
#       <td id="T_a1ca9_row4_col1" class="data row4 col1" >NYSEArca</td>
#       <td id="T_a1ca9_row4_col2" class="data row4 col2" >1993-01-22</td>
#       <td id="T_a1ca9_row4_col3" class="data row4 col3" >Blend</td>
#       <td id="T_a1ca9_row4_col4" class="data row4 col4" >Large</td>
#       <td id="T_a1ca9_row4_col5" class="data row4 col5" >76940463</td>
#       <td id="T_a1ca9_row4_col6" class="data row4 col6" >0.000940</td>
#       <td id="T_a1ca9_row4_col7" class="data row4 col7" >0.147100</td>
#       <td id="T_a1ca9_row4_col8" class="data row4 col8" >13.560000</td>
#       <td id="T_a1ca9_row4_col9" class="data row4 col9" >1.040000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Performance 5y focused
# - High sharpe ratio
# - Sharpe ratio > 1.1
# - 5year STD  < 22%
# - Avg_volum_3months > 1%SPY

# %%
window_str = "5years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)

df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]


df_display = df_display[df_display["fund_sharpe_ratio_3years"] >= 1.1]

df_display = df_display[df_display[f"fund_stdev_5years"] < 22]

df_display[
    list(df_etfs.columns[0:1])
    +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        "fund_return_5years",
        f"fund_stdev_5years",
        f"fund_sharpe_ratio_5years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_13a74 th {
#   max-width: 80px;
# }
# #T_13a74 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_13a74 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_13a74_row0_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_13a74_row0_col6 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_13a74_row0_col7, #T_13a74_row0_col8, #T_13a74_row0_col9, #T_13a74_row1_col6, #T_13a74_row2_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_13a74_row1_col5, #T_13a74_row4_col6, #T_13a74_row5_col5, #T_13a74_row6_col5, #T_13a74_row6_col7, #T_13a74_row6_col8, #T_13a74_row6_col9 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_13a74_row1_col7 {
#   background-color: #797979;
#   color: #f1f1f1;
# }
# #T_13a74_row1_col8 {
#   background-color: #979797;
#   color: #f1f1f1;
# }
# #T_13a74_row1_col9 {
#   background-color: #242424;
#   color: #f1f1f1;
# }
# #T_13a74_row2_col6 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_13a74_row2_col7 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_13a74_row2_col8 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_13a74_row2_col9 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_13a74_row3_col5, #T_13a74_row4_col5 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_13a74_row3_col6 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_13a74_row3_col7 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_13a74_row3_col8 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_13a74_row3_col9 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_13a74_row4_col7 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_13a74_row4_col8 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_13a74_row4_col9 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_13a74_row5_col6 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_13a74_row5_col7 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_13a74_row5_col8, #T_13a74_row5_col9 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_13a74_row6_col6 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13a74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13a74_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_13a74_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_13a74_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_13a74_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_13a74_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_13a74_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_13a74_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_13a74_level0_col7" class="col_heading level0 col7" >fund_return_5years</th>
#       <th id="T_13a74_level0_col8" class="col_heading level0 col8" >fund_stdev_5years</th>
#       <th id="T_13a74_level0_col9" class="col_heading level0 col9" >fund_sharpe_ratio_5years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13a74_level0_row0" class="row_heading level0 row0" >1697</th>
#       <td id="T_13a74_row0_col0" class="data row0 col0" >SMH</td>
#       <td id="T_13a74_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_13a74_row0_col2" class="data row0 col2" >2011-12-20</td>
#       <td id="T_13a74_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_13a74_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_13a74_row0_col5" class="data row0 col5" >3470350</td>
#       <td id="T_13a74_row0_col6" class="data row0 col6" >0.003500</td>
#       <td id="T_13a74_row0_col7" class="data row0 col7" >0.374100</td>
#       <td id="T_13a74_row0_col8" class="data row0 col8" >21.710000</td>
#       <td id="T_13a74_row0_col9" class="data row0 col9" >1.530000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row1" class="row_heading level0 row1" >2212</th>
#       <td id="T_13a74_row1_col0" class="data row1 col0" >IGV</td>
#       <td id="T_13a74_row1_col1" class="data row1 col1" >BATS</td>
#       <td id="T_13a74_row1_col2" class="data row1 col2" >2001-07-10</td>
#       <td id="T_13a74_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_13a74_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_13a74_row1_col5" class="data row1 col5" >1090682</td>
#       <td id="T_13a74_row1_col6" class="data row1 col6" >0.004600</td>
#       <td id="T_13a74_row1_col7" class="data row1 col7" >0.302200</td>
#       <td id="T_13a74_row1_col8" class="data row1 col8" >18.180000</td>
#       <td id="T_13a74_row1_col9" class="data row1 col9" >1.490000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row2" class="row_heading level0 row2" >1498</th>
#       <td id="T_13a74_row2_col0" class="data row2 col0" >QQQ</td>
#       <td id="T_13a74_row2_col1" class="data row2 col1" >NasdaqGM</td>
#       <td id="T_13a74_row2_col2" class="data row2 col2" >1999-03-10</td>
#       <td id="T_13a74_row2_col3" class="data row2 col3" >Growth</td>
#       <td id="T_13a74_row2_col4" class="data row2 col4" >Large</td>
#       <td id="T_13a74_row2_col5" class="data row2 col5" >46374673</td>
#       <td id="T_13a74_row2_col6" class="data row2 col6" >0.002000</td>
#       <td id="T_13a74_row2_col7" class="data row2 col7" >0.279800</td>
#       <td id="T_13a74_row2_col8" class="data row2 col8" >16.890000</td>
#       <td id="T_13a74_row2_col9" class="data row2 col9" >1.480000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row3" class="row_heading level0 row3" >2244</th>
#       <td id="T_13a74_row3_col0" class="data row3 col0" >IWF</td>
#       <td id="T_13a74_row3_col1" class="data row3 col1" >NYSEArca</td>
#       <td id="T_13a74_row3_col2" class="data row3 col2" >2000-05-22</td>
#       <td id="T_13a74_row3_col3" class="data row3 col3" >Growth</td>
#       <td id="T_13a74_row3_col4" class="data row3 col4" >Large</td>
#       <td id="T_13a74_row3_col5" class="data row3 col5" >1707365</td>
#       <td id="T_13a74_row3_col6" class="data row3 col6" >0.001900</td>
#       <td id="T_13a74_row3_col7" class="data row3 col7" >0.234200</td>
#       <td id="T_13a74_row3_col8" class="data row3 col8" >16.100000</td>
#       <td id="T_13a74_row3_col9" class="data row3 col9" >1.320000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row4" class="row_heading level0 row4" >2240</th>
#       <td id="T_13a74_row4_col0" class="data row4 col0" >IVW</td>
#       <td id="T_13a74_row4_col1" class="data row4 col1" >NYSEArca</td>
#       <td id="T_13a74_row4_col2" class="data row4 col2" >2000-05-22</td>
#       <td id="T_13a74_row4_col3" class="data row4 col3" >Growth</td>
#       <td id="T_13a74_row4_col4" class="data row4 col4" >Large</td>
#       <td id="T_13a74_row4_col5" class="data row4 col5" >1835620</td>
#       <td id="T_13a74_row4_col6" class="data row4 col6" >0.001800</td>
#       <td id="T_13a74_row4_col7" class="data row4 col7" >0.216100</td>
#       <td id="T_13a74_row4_col8" class="data row4 col8" >15.290000</td>
#       <td id="T_13a74_row4_col9" class="data row4 col9" >1.290000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row5" class="row_heading level0 row5" >2215</th>
#       <td id="T_13a74_row5_col0" class="data row5 col0" >IHI</td>
#       <td id="T_13a74_row5_col1" class="data row5 col1" >NYSEArca</td>
#       <td id="T_13a74_row5_col2" class="data row5 col2" >2006-05-01</td>
#       <td id="T_13a74_row5_col3" class="data row5 col3" >Growth</td>
#       <td id="T_13a74_row5_col4" class="data row5 col4" >Large</td>
#       <td id="T_13a74_row5_col5" class="data row5 col5" >939369</td>
#       <td id="T_13a74_row5_col6" class="data row5 col6" >0.004200</td>
#       <td id="T_13a74_row5_col7" class="data row5 col7" >0.220700</td>
#       <td id="T_13a74_row5_col8" class="data row5 col8" >15.980000</td>
#       <td id="T_13a74_row5_col9" class="data row5 col9" >1.260000</td>
#     </tr>
#     <tr>
#       <th id="T_13a74_level0_row6" class="row_heading le

# %% [markdown]
# ### Performance 3y focused
# - High sharpe ratio
# - Returns >= 10%
# - Sharpe ratio > 1.1
# - Long term STD  < 30%
# - Avg_volum_3months > 1%SPY

# %%
window_str = "3years"

df_display = df_etfs.sort_values(
    by=[f"fund_sharpe_ratio_{window_str}"], ascending=False
)

spy_loc = df_display.index.get_loc(
    df_display[df_display["fund_symbol"] == "SPY"].iloc[-1].name
)
df_display = df_display.head(spy_loc + 1)

df_display = df_display[
    df_display["avg_vol_3month"]
    >= (0.01 * df_display["avg_vol_3month"][df_display["fund_symbol"] == "SPY"].iloc[0])
]


df_display = df_display[df_display["fund_sharpe_ratio_3years"] >= 1.1]

df_display = df_display[df_display[f"fund_stdev_3years"] < 30]
df_display = df_display[df_display[f"fund_return_3years"] > 0.1]


df_display[
    list(df_etfs.columns[0:1])
    +
    list(df_etfs.columns[9:10])
    + [
        "inception_date",
        "investment_type",
        "size_type",
        "avg_vol_3month",
        "fund_annual_report_net_expense_ratio",
        "fund_return_3years",
        f"fund_stdev_3years",
        f"fund_sharpe_ratio_3years",
    ]
].style.set_table_styles(PANDAS_STYLE_VERTICAL_COLNAMES).background_gradient(
    cmap="Greys"
).set_sticky(
    axis=1
)
# Out:
# <style type="text/css">
# #T_b6248 th {
#   max-width: 80px;
# }
# #T_b6248 th.col_heading {
#   writing-mode: vertical-rl;
#   transform: rotateZ(-180deg);
# }
# #T_b6248 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_b6248_row0_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_b6248_row0_col6 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_b6248_row0_col7, #T_b6248_row0_col8, #T_b6248_row0_col9, #T_b6248_row1_col5, #T_b6248_row2_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b6248_row1_col6, #T_b6248_row6_col8 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_b6248_row1_col7 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_b6248_row1_col8 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_b6248_row1_col9, #T_b6248_row2_col8 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_b6248_row2_col5, #T_b6248_row4_col5, #T_b6248_row4_col7, #T_b6248_row4_col8, #T_b6248_row5_col6, #T_b6248_row6_col5, #T_b6248_row6_col9 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b6248_row2_col7 {
#   background-color: #adadad;
#   color: #000000;
# }
# #T_b6248_row2_col9 {
#   background-color: #b2b2b2;
#   color: #000000;
# }
# #T_b6248_row3_col5, #T_b6248_row5_col5, #T_b6248_row6_col7 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_b6248_row3_col6, #T_b6248_row4_col9, #T_b6248_row5_col9 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_b6248_row3_col7 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_b6248_row3_col8 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_b6248_row3_col9 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_b6248_row4_col6 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_b6248_row5_col7 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_b6248_row5_col8 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_b6248_row6_col6 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6248">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6248_level0_col0" class="col_heading level0 col0" >fund_symbol</th>
#       <th id="T_b6248_level0_col1" class="col_heading level0 col1" >exchange_name</th>
#       <th id="T_b6248_level0_col2" class="col_heading level0 col2" >inception_date</th>
#       <th id="T_b6248_level0_col3" class="col_heading level0 col3" >investment_type</th>
#       <th id="T_b6248_level0_col4" class="col_heading level0 col4" >size_type</th>
#       <th id="T_b6248_level0_col5" class="col_heading level0 col5" >avg_vol_3month</th>
#       <th id="T_b6248_level0_col6" class="col_heading level0 col6" >fund_annual_report_net_expense_ratio</th>
#       <th id="T_b6248_level0_col7" class="col_heading level0 col7" >fund_return_3years</th>
#       <th id="T_b6248_level0_col8" class="col_heading level0 col8" >fund_stdev_3years</th>
#       <th id="T_b6248_level0_col9" class="col_heading level0 col9" >fund_sharpe_ratio_3years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6248_level0_row0" class="row_heading level0 row0" >1697</th>
#       <td id="T_b6248_row0_col0" class="data row0 col0" >SMH</td>
#       <td id="T_b6248_row0_col1" class="data row0 col1" >NasdaqGM</td>
#       <td id="T_b6248_row0_col2" class="data row0 col2" >2011-12-20</td>
#       <td id="T_b6248_row0_col3" class="data row0 col3" >Growth</td>
#       <td id="T_b6248_row0_col4" class="data row0 col4" >Large</td>
#       <td id="T_b6248_row0_col5" class="data row0 col5" >3470350</td>
#       <td id="T_b6248_row0_col6" class="data row0 col6" >0.003500</td>
#       <td id="T_b6248_row0_col7" class="data row0 col7" >0.385700</td>
#       <td id="T_b6248_row0_col8" class="data row0 col8" >24.660000</td>
#       <td id="T_b6248_row0_col9" class="data row0 col9" >1.410000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row1" class="row_heading level0 row1" >1498</th>
#       <td id="T_b6248_row1_col0" class="data row1 col0" >QQQ</td>
#       <td id="T_b6248_row1_col1" class="data row1 col1" >NasdaqGM</td>
#       <td id="T_b6248_row1_col2" class="data row1 col2" >1999-03-10</td>
#       <td id="T_b6248_row1_col3" class="data row1 col3" >Growth</td>
#       <td id="T_b6248_row1_col4" class="data row1 col4" >Large</td>
#       <td id="T_b6248_row1_col5" class="data row1 col5" >46374673</td>
#       <td id="T_b6248_row1_col6" class="data row1 col6" >0.002000</td>
#       <td id="T_b6248_row1_col7" class="data row1 col7" >0.282900</td>
#       <td id="T_b6248_row1_col8" class="data row1 col8" >20.240000</td>
#       <td id="T_b6248_row1_col9" class="data row1 col9" >1.280000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row2" class="row_heading level0 row2" >2212</th>
#       <td id="T_b6248_row2_col0" class="data row2 col0" >IGV</td>
#       <td id="T_b6248_row2_col1" class="data row2 col1" >BATS</td>
#       <td id="T_b6248_row2_col2" class="data row2 col2" >2001-07-10</td>
#       <td id="T_b6248_row2_col3" class="data row2 col3" >Growth</td>
#       <td id="T_b6248_row2_col4" class="data row2 col4" >Large</td>
#       <td id="T_b6248_row2_col5" class="data row2 col5" >1090682</td>
#       <td id="T_b6248_row2_col6" class="data row2 col6" >0.004600</td>
#       <td id="T_b6248_row2_col7" class="data row2 col7" >0.290900</td>
#       <td id="T_b6248_row2_col8" class="data row2 col8" >21.670000</td>
#       <td id="T_b6248_row2_col9" class="data row2 col9" >1.240000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row3" class="row_heading level0 row3" >2244</th>
#       <td id="T_b6248_row3_col0" class="data row3 col0" >IWF</td>
#       <td id="T_b6248_row3_col1" class="data row3 col1" >NYSEArca</td>
#       <td id="T_b6248_row3_col2" class="data row3 col2" >2000-05-22</td>
#       <td id="T_b6248_row3_col3" class="data row3 col3" >Growth</td>
#       <td id="T_b6248_row3_col4" class="data row3 col4" >Large</td>
#       <td id="T_b6248_row3_col5" class="data row3 col5" >1707365</td>
#       <td id="T_b6248_row3_col6" class="data row3 col6" >0.001900</td>
#       <td id="T_b6248_row3_col7" class="data row3 col7" >0.248700</td>
#       <td id="T_b6248_row3_col8" class="data row3 col8" >19.780000</td>
#       <td id="T_b6248_row3_col9" class="data row3 col9" >1.160000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row4" class="row_heading level0 row4" >2215</th>
#       <td id="T_b6248_row4_col0" class="data row4 col0" >IHI</td>
#       <td id="T_b6248_row4_col1" class="data row4 col1" >NYSEArca</td>
#       <td id="T_b6248_row4_col2" class="data row4 col2" >2006-05-01</td>
#       <td id="T_b6248_row4_col3" class="data row4 col3" >Growth</td>
#       <td id="T_b6248_row4_col4" class="data row4 col4" >Large</td>
#       <td id="T_b6248_row4_col5" class="data row4 col5" >939369</td>
#       <td id="T_b6248_row4_col6" class="data row4 col6" >0.004200</td>
#       <td id="T_b6248_row4_col7" class="data row4 col7" >0.220000</td>
#       <td id="T_b6248_row4_col8" class="data row4 col8" >17.970000</td>
#       <td id="T_b6248_row4_col9" class="data row4 col9" >1.130000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row5" class="row_heading level0 row5" >2240</th>
#       <td id="T_b6248_row5_col0" class="data row5 col0" >IVW</td>
#       <td id="T_b6248_row5_col1" class="data row5 col1" >NYSEArca</td>
#       <td id="T_b6248_row5_col2" class="data row5 col2" >2000-05-22</td>
#       <td id="T_b6248_row5_col3" class="data row5 col3" >Growth</td>
#       <td id="T_b6248_row5_col4" class="data row5 col4" >Large</td>
#       <td id="T_b6248_row5_col5" class="data row5 col5" >1835620</td>
#       <td id="T_b6248_row5_col6" class="data row5 col6" >0.001800</td>
#       <td id="T_b6248_row5_col7" class="data row5 col7" >0.228800</td>
#       <td id="T_b6248_row5_col8" class="data row5 col8" >18.730000</td>
#       <td id="T_b6248_row5_col9" class="data row5 col9" >1.130000</td>
#     </tr>
#     <tr>
#       <th id="T_b6248_level0_row6" class="row_heading level0 row6" >296</th>
#       <td id="T_b6248_row6_col0" class="data row6 col0" >CWB</td>
#       <td id="T_b6248_row6_col1" class="data row6 col1" >NYSEArca</td>
#       <td id="T_b6248_row6_col2" class="da
